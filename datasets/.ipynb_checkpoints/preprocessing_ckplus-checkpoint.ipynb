# %%
import os
import cv2
import sys
import logging
import numpy as np
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# %% [markdown]
# ### Changes made to MTCNN to suppress logs and warnings:
#    - **File**: `~/anaconda3/envs/<env_name>/Lib/site-packages/mtcnn/mtcnn.py`
#
# 1. **Suppressed verbose output during predictions:**
#    - Modified the following lines to include `verbose=False`:
#      - Line 342: `self._pnet.predict(img_y, verbose=False)`
#      - Line 410: `self._rnet.predict(tempimg1, verbose=False)`
#      - Line 466: `self._onet.predict(tempimg1, verbose=False)`
#
# 2. **Fixed warning condition:**
#    - Line 206: Changed `if method is 'Min'` to `if method == 'Min'`.

# %%
INPUT_FOLDER = "C:/Users/ceyda/facial_emotion_detection_dataset/test"
OUTPUT_FOLDER = "C:/Users/ceyda/facial_emotion_detection_dataset_cropped"  
TARGET_SIZE = (48, 48)

# %%
os.makedirs(OUTPUT_FOLDER, exist_ok=True)
detector = MTCNN()

for root, dirs, files in os.walk(INPUT_FOLDER):
    for filename in files:
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):

            file_path = os.path.join(root, filename)
            img_gray = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)

            if img_gray is None:
                print(f"{filename} cannot be loaded.")
                continue

            # Convert grayscale to pseudo RGB for MTCNN
            img_rgb = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2RGB)
            faces = detector.detect_faces(img_rgb)
            if faces:
                x, y, width, height = faces[0]['box']
                x, y = max(0, x), max(0, y)  

                face = img_gray[y:y + height, x:x + width]  
                face_resized = cv2.resize(face, TARGET_SIZE)  
                save_path = os.path.join(OUTPUT_FOLDER, os.path.relpath(file_path, INPUT_FOLDER))
                os.makedirs(os.path.dirname(save_path), exist_ok=True) 
                cv2.imwrite(save_path, face_resized)
                
            else:
                img_resized = cv2.resize(img_gray, TARGET_SIZE)
                save_path = os.path.join(root, filename) 
                cv2.imwrite(save_path, img_resized)
# Out:
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-103.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-105.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-11.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-110.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-115.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-127.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-130.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-131.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-135.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-148.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-149.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-150.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-16.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-187.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-205.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-218.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-224.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-227.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-255.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-266.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-269.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-270.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-273.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-281.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-286.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-287.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-297.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-30.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-309.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-314.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-325.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-326.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-335.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-339.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-377.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-38.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-386.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-389.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-394.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-404.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-418.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-42.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-438.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-442.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-448.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-453.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-455.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-458.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-476.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-486.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-489.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-50.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-503.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-512.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-527.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-528.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-546.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-549.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-552.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-557.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-558.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-57.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-573.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-588.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-59.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-592.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-6.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-600.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-604.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-61.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-613.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-615.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-62.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-626.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-632.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-633.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-637.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-642.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-645.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-647.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-660.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-661.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-666.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-670.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-68.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-685.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-700.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-720.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-723.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-733.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-746.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-75.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-754.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-760.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-761.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-764.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-773.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-790.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-792.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-793.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-796.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-798.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-807.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-821.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-825.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-835.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-843.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-848.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-850.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-862.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-867.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-874.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-881.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-889.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-897.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-91.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-912.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-913.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-914.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-916.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-917.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-92.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-929.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-932.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-936.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-937.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-938.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-946.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-949.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-950.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\angry\image-953.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-100.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-105.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-109.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-111.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-20.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-23.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-24.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-34.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-37.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-39.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-41.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-44.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-46.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-55.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-56.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-58.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-6.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-78.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-81.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-85.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-86.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-88.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\disgust\image-92.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-1000.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-1001.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-1002.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-1004.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-1012.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-1017.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-106.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-110.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-120.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-121.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-125.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-128.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-131.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-134.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-137.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-146.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-147.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-154.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-155.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-16.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-161.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-162.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-17.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-180.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-189.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-191.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-20.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-200.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-202.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-207.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-229.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-243.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-252.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-258.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-261.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-268.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-273.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-274.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-279.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-283.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-284.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-287.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-293.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-294.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-295.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-296.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-297.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-305.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-308.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-322.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-329.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-333.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-337.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-338.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-346.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-349.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-355.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-386.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-387.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-39.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-399.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-4.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-40.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-408.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-415.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-418.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-434.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-439.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-44.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-441.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-447.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-452.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-457.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-459.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-464.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-468.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-475.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-478.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-485.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-486.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-490.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-491.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-5.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-505.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-509.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-510.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-511.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-512.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-513.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-517.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-520.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-522.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-527.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-531.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-532.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-535.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-540.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-543.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-556.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-560.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-564.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-565.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-567.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-577.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-581.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-590.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-593.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-594.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-595.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-598.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-599.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-610.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-612.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-618.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-62.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-620.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-622.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-624.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-635.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-638.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-640.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-648.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-650.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-658.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-66.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-660.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-662.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-663.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-666.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-679.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-682.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-693.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-710.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-711.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-720.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-724.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-737.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-740.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-744.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-746.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-747.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-754.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-755.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-760.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-773.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-784.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-791.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-796.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-797.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-802.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-804.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-807.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-810.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-816.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-817.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-82.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-821.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-825.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-838.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-84.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-847.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-850.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-851.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-853.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-86.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-860.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-884.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-890.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-9.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-900.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-905.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-912.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-923.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-928.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-937.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-947.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-948.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-949.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-963.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-968.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-970.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-973.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-976.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-978.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-979.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\fear\image-992.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-10.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-101.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1012.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1023.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1025.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-104.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1045.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1055.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-106.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1070.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1071.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1076.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1086.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1090.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1092.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1093.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1094.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1111.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1118.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1122.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1124.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1132.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1135.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1146.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1150.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1152.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1160.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1162.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-119.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1194.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-120.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1211.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1213.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1229.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1239.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1252.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1256.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-126.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1260.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1264.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1272.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-128.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1289.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-129.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1293.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1297.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-130.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1314.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1323.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-133.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-134.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1341.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1358.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1359.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1370.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1373.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1375.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1394.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1405.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1417.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1429.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1438.jpg CANNOT FIND A FACE.
# C:/Users/ceyda/facial_emotion_detection_dataset/test\happy\image-1446.jpg CANNOT FIND A FACE.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 17
#      15 # Convert grayscale to pseudo RGB for MTCNN
#      16 img_rgb = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2RGB)
# ---> 17 faces = detector.detect_faces(img_rgb)
#      18 if faces:
#      19     x, y, width, height = faces[0]['box']
#
# File ~\anaconda3\envs\tf\lib\site-packages\mtcnn\mtcnn.py:300, in MTCNN.detect_faces(self, img)
#     298 # We pipe here each of the stages
#     299 for stage in stages:
# --> 300     result = stage(img, result[0], result[1])
#     302 [total_boxes, points] = result
#     304 bounding_boxes = []
#
# File ~\anaconda3\envs\tf\lib\site-packages\mtcnn\mtcnn.py:342, in MTCNN.__stage1(self, image, scales, stage_status)
#     339 img_x = np.expand_dims(scaled_image, 0)
#     340 img_y = np.transpose(img_x, (0, 2, 1, 3))
# --> 342 out = self._pnet.predict(img_y, verbose=0)
#     344 out0 = np.transpose(out[0], (0, 2, 1, 3))
#     345 out1 = np.transpose(out[1], (0, 2, 1, 3))
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:
